# %% [markdown]
# # [DataFrame 인덱스 다루기]
# - (1) 새로운 인덱스 설정 : 컬럼 ==> 인덱스 설정

# %% [markdown]
# ### (1~) 데이터 준비

# %%
# 1. 데이터 준비
import pandas as pd

# 2. 데이터 입력
exam = {'이름' :['갓기','현길', '시명', '주영'],
        '국어' : [60, 70, 100, 90],
        '미술' : [80, 20, 40, 80],
        '수학' : [90, 100, 90, 60],
        '체육' : [0, 30, 70, 50]}

# 3. 데이터 저장
examDF = pd.DataFrame(exam)
examDF
# Out:
#    이름   국어  미술   수학  체육
# 0  갓기   60  80   90   0
# 1  현길   70  20  100  30
# 2  시명  100  40   90  70
# 3  주영   90  80   60  50

# %% [markdown]
# ### (5-1) 새로운 인덱스 설정 - 방법 1 : 인덱스 일부 변경 DF.rename()

# %%
# 1. 행 인덱스 일부 변경 => {기존 인덱스:새로운 인덱스}
# .rename(index={_old:_new}, [inplace=False])
examDF.rename(index={0:'zero'})
# Out:
#       이름   국어  미술   수학  체육
# zero  갓기   60  80   90   0
# 1     현길   70  20  100  30
# 2     시명  100  40   90  70
# 3     주영   90  80   60  50

# %%
examDF    # inplace=False : 기본적으로 원본을 건들지 않는다
# Out:
#    이름   국어  미술   수학  체육
# 0  갓기   60  80   90   0
# 1  현길   70  20  100  30
# 2  시명  100  40   90  70
# 3  주영   90  80   60  50

# %%
# inplace=True : 원본 자체를 바꿔버린다!
# 기본은 변경 안하는 것
examDF.rename(index={0:'zero'}, inplace=True)
examDF
# Out:
#       이름   국어  미술   수학  체육
# zero  갓기   60  80   90   0
# 1     현길   70  20  100  30
# 2     시명  100  40   90  70
# 3     주영   90  80   60  50

# %%
# 2. 열 이름 인덱스 일부 변경 => columns ={_old:_new}
examDF.rename(columns={'체육':'음악'}, inplace=True)
examDF.columns
# Out:
# Index(['이름', '국어', '미술', '수학', '음악'], dtype='object')

# %% [markdown]
# ### (5-2) 새로운 인덱스 설정 - 방법 2 : .set_index ; 기존 열을 인덱스로 만들기
# - .set_index(['col'])    => 이러면 여러 열을 인덱스로 할 수 있다
# - .set_index('col')

# %%
# 1. 1개 컬럼을 인덱스로 설정. 단, inplace=False : 원본 적용 안됨
examDF.set_index(['이름'])
# Out:
#      국어  미술   수학  음악
# 이름
# 갓기   60  80   90   0
# 현길   70  20  100  30
# 시명  100  40   90  70
# 주영   90  80   60  50

# %%
examDF.set_index('이름')
# Out:
#      국어  미술   수학  음악
# 이름
# 갓기   60  80   90   0
# 현길   70  20  100  30
# 시명  100  40   90  70
# 주영   90  80   60  50

# %%
# 여러 열을 인덱스로 만들기 => 가능!
# 사용 예: 성, 이름
examDF.set_index(['이름','국어'])
# Out:
#         미술   수학  음악
# 이름 국어
# 갓기 60   80   90   0
# 현길 70   20  100  30
# 시명 100  40   90  70
# 주영 90   80   60  50

# %%
examDF.set_index('이름','수학')
# Out:
# <ipython-input-47-bedfb47c5793>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   examDF.set_index('이름','수학')
#      국어  미술   수학  음악
# 이름
# 갓기   60  80   90   0
# 현길   70  20  100  30
# 시명  100  40   90  70
# 주영   90  80   60  50

# %%
# 복수 인덱스의 호출 : 모두 불러야 호출된다

examDF2 = examDF.set_index(['이름','국어'])
# examDF.loc['갓기']
examDF2.loc[('갓기',60)]
# Out:
# 미술    80
# 수학    90
# 음악     0
# Name: (갓기, 60), dtype: int64

# %%
# 하나만 호출 : 나머지 멀티 인덱스가 포함된 데이터프레임으로 출력
# -> 성능에 좋지 않음
examDF2.loc['갓기']
# Out:
#     미술  수학  음악
# 국어
# 60  80  90   0

# %%
# 맨 앞 인덱스가 아니면: 오류 발생
# -> 맨 앞 인덱스부터 찾기 때문
# examDF2.loc[60]

# %% [markdown]
# ### (5-3) 새로운 인덱스 설정 방법 3: 인덱스 리셋

# %%
# .reset_index( [inplace=False] )
# => 현재 행 인덱스를 컬럼으로 추가
examDF.reset_index(inplace=True)
examDF
# Out:
#   index  이름   국어  미술   수학  음악
# 0  zero  갓기   60  80   90   0
# 1     1  현길   70  20  100  30
# 2     2  시명  100  40   90  70
# 3     3  주영   90  80   60  50

# %%
# .reset_index 는 인덱스를 밀어 넣는 것: 0~ 의 인덱스를 열에 계속 추가
examDF.reset_index().reset_index()  # 엥 다시하니까 왜 오류 나지
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-e49b2661fcc3> in <cell line: 2>()
#       1 # .reset_index 는 인덱스를 밀어 넣는 것: 0~ 의 인덱스를 열에 계속 추가
# ----> 2 examDF.reset_index().reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6359                     )
#    6360
# -> 6361                 new_obj.insert(
#    6362                     0,
#    6363                     name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %%
# drop=True : 인덱스를 리셋하면서 열로 넣지 않음
df2 = examDF.reset_index(drop=True)
df2
# Out:
#   index  이름   국어  미술   수학  음악
# 0  zero  갓기   60  80   90   0
# 1     1  현길   70  20  100  30
# 2     2  시명  100  40   90  70
# 3     3  주영   90  80   60  50
