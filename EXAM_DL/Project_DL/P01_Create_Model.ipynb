# %% [markdown]
# 주제 : 환경을 분석해 사람에게 도움이 되는 모델 생성
#
# 구성 :
# 1. 사진 데이터 수집
# 2. 사진 데이터 전처리
# 3. 데이터셋 구성
# 4. 데이터로더 구성
# 5. 모델 구성
# 6. 모델 학습
# 7. 모델 평가
# 8. 모델 저장 및 불러오기
# 9. 모델 예측
# 10. 프로젝트 정리
#
# 개인 주제 : 뱀의 독성 확인

# %%
# 이미지 불러오기 : cv2.imread()
# 이미지 보여주기 : cv2.imshow()

import cv2

# 이미지 흑백으로 불러오기
img = cv2.imread('Snake Images/train/Non Venomous/0 (2).jpg', cv2.IMREAD_GRAYSCALE)

# 이미지 보여주기
cv2.imshow('image', img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 # 이미지 불러오기 : cv2.imread()
#       2 # 이미지 보여주기 : cv2.imshow()
# ----> 4 import cv2
#       6 # 이미지 흑백으로 불러오기
#       7 img = cv2.imread('Snake Images/train/Non Venomous/0 (2).jpg', cv2.IMREAD_GRAYSCALE)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms


# Load the dataset
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Create the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Define your deep learning model and train it
# ...

# Evaluate the model
# ...

# %%
# 컬러 이미지를 흑백으로 바꾸기
transform = transforms.Compose([transforms.Grayscale(num_output_channels=1),
                                transforms.ToTensor()])
